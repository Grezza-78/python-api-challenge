# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 625

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bolshoye polpino
# City not found. Skipping...
# Processing Record 4 of Set 1 | san luis
# Processing Record 5 of Set 1 | ust-maya
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | lyantonde
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | kavieng
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | acapulco
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | nome
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | coos bay
# Processing Record 23 of Set 1 | puerto escondido
# Processing Record 24 of Set 1 | barcelos
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | saint-joseph
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | hay river
# Processing Record 35 of Set 1 | bima
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | bacalar
# Processing Record 39 of Set 1 | ambon
# Processing Record 40 of Set 1 | prachuap khiri khan
# Processing Record 41 of Set 1 | flinders
# Processing Record 42 of Set 1 | adrar
# Processing Record 43 of Set 1 | okha
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | antofagasta
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | conceicao do araguaia
# Processing Record 0 of Set 2 | sterling
# Processing Record 1 of Set 2 | aguimes
# Processing Record 2 of Set 2 | kahului
# Processing Record 3 of Set 2 | arica
# Processing Record 4 of Set 2 | soyo
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | noumea
# Processing Record 8 of Set 2 | spas-klepiki
# Processing Record 9 of Set 2 | puerto cabezas
# Processing Record 10 of Set 2 | ghanzi
# Processing Record 11 of Set 2 | kloulklubed
# Processing Record 12 of Set 2 | kintampo
# Processing Record 13 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 2 | lagoa
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | riyadh
# Processing Record 18 of Set 2 | kununurra
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | alofi
# Processing Record 22 of Set 2 | comodoro rivadavia
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | uribia
# Processing Record 27 of Set 2 | natal
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | nuevo progreso
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | christchurch
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | hauzenberg
# Processing Record 37 of Set 2 | olafsvik
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | ladario
# Processing Record 41 of Set 2 | raver
# Processing Record 42 of Set 2 | ixtapa
# Processing Record 43 of Set 2 | tibati
# Processing Record 44 of Set 2 | abashiri
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | qasigiannguit
# Processing Record 49 of Set 2 | khatanga
# Processing Record 0 of Set 3 | kenai
# Processing Record 1 of Set 3 | kalmunai
# Processing Record 2 of Set 3 | arrecife
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | fairbanks
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | bakel
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | korla
# Processing Record 13 of Set 3 | boyuibe
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | nagato
# Processing Record 16 of Set 3 | sao francisco de assis
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | cayenne
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | busselton
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | arman
# Processing Record 24 of Set 3 | brewer
# Processing Record 25 of Set 3 | kanye
# Processing Record 26 of Set 3 | sabha
# Processing Record 27 of Set 3 | nokaneng
# Processing Record 28 of Set 3 | brae
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | waingapu
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | pangnirtung
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | chengdu
# Processing Record 37 of Set 3 | huarmey
# Processing Record 38 of Set 3 | ramsar
# Processing Record 39 of Set 3 | leningradskiy
# Processing Record 40 of Set 3 | tazovskiy
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | howard springs
# Processing Record 43 of Set 3 | salinas
# Processing Record 44 of Set 3 | miri
# Processing Record 45 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 3 | teluknaga
# Processing Record 47 of Set 3 | mawlaik
# Processing Record 48 of Set 3 | skibbereen
# Processing Record 49 of Set 3 | salalah
# Processing Record 0 of Set 4 | halifax
# Processing Record 1 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | rajamahendri
# City not found. Skipping...
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | komsomolskiy
# Processing Record 6 of Set 4 | ugoofaaru
# Processing Record 7 of Set 4 | ambilobe
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | ambulu
# Processing Record 12 of Set 4 | quatre cocos
# Processing Record 13 of Set 4 | maralal
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | lantawan
# Processing Record 16 of Set 4 | gamba
# Processing Record 17 of Set 4 | paraiso
# Processing Record 18 of Set 4 | mongo
# Processing Record 19 of Set 4 | tura
# Processing Record 20 of Set 4 | odweyne
# Processing Record 21 of Set 4 | lappersdorf
# Processing Record 22 of Set 4 | neepawa
# Processing Record 23 of Set 4 | ivaipora
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | bintulu
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | suba
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | henties bay
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | punta alta
# Processing Record 39 of Set 4 | palafrugell
# Processing Record 40 of Set 4 | sakakah
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | saint-pierre
# Processing Record 44 of Set 4 | ambunti
# Processing Record 45 of Set 4 | gravdal
# Processing Record 46 of Set 4 | chirongui
# Processing Record 47 of Set 4 | nioro
# Processing Record 48 of Set 4 | strasshof
# City not found. Skipping...
# Processing Record 49 of Set 4 | madhugiri
# Processing Record 0 of Set 5 | pozo colorado
# Processing Record 1 of Set 5 | chapleau
# Processing Record 2 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 3 of Set 5 | saint-leu
# Processing Record 4 of Set 5 | porto novo
# Processing Record 5 of Set 5 | palma
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | jinotega
# Processing Record 8 of Set 5 | vila velha
# Processing Record 9 of Set 5 | aksarka
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | praxedis guerrero
# Processing Record 12 of Set 5 | xifeng
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | cody
# Processing Record 15 of Set 5 | tiarei
# Processing Record 16 of Set 5 | manapparai
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | rio gallegos
# Processing Record 20 of Set 5 | quelimane
# Processing Record 21 of Set 5 | sioux falls
# Processing Record 22 of Set 5 | valley city
# Processing Record 23 of Set 5 | sindor
# Processing Record 24 of Set 5 | sao jose da coroa grande
# Processing Record 25 of Set 5 | eenhana
# Processing Record 26 of Set 5 | haines junction
# Processing Record 27 of Set 5 | buluang
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | tabas
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | whitehorse
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | campo grande
# Processing Record 36 of Set 5 | muyezerskiy
# Processing Record 37 of Set 5 | buje
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | zabaykalsk
# Processing Record 40 of Set 5 | gisborne
# Processing Record 41 of Set 5 | tasiilaq
# Processing Record 42 of Set 5 | jiaocheng
# Processing Record 43 of Set 5 | krasnovishersk
# Processing Record 44 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 5 | jalu
# Processing Record 48 of Set 5 | oschatz
# Processing Record 49 of Set 5 | necochea
# Processing Record 0 of Set 6 | gorontalo
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | osoyoos
# Processing Record 3 of Set 6 | paka
# Processing Record 4 of Set 6 | shibarghan
# City not found. Skipping...
# Processing Record 5 of Set 6 | tangkak
# Processing Record 6 of Set 6 | maputo
# Processing Record 7 of Set 6 | oranjemund
# Processing Record 8 of Set 6 | tikaitnagar
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | lompoc
# Processing Record 11 of Set 6 | crossville
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | ovalle
# Processing Record 14 of Set 6 | palaikastron
# Processing Record 15 of Set 6 | evensk
# Processing Record 16 of Set 6 | xuddur
# Processing Record 17 of Set 6 | santa vitoria do palmar
# Processing Record 18 of Set 6 | barra do garcas
# Processing Record 19 of Set 6 | saint-philippe
# Processing Record 20 of Set 6 | mormugao
# Processing Record 21 of Set 6 | walvis bay
# Processing Record 22 of Set 6 | denpasar
# Processing Record 23 of Set 6 | watertown
# Processing Record 24 of Set 6 | vostok
# Processing Record 25 of Set 6 | samarai
# Processing Record 26 of Set 6 | tiznit
# Processing Record 27 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | livani
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | sisophon
# Processing Record 31 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | sassandra
# Processing Record 34 of Set 6 | zambezi
# Processing Record 35 of Set 6 | boyolangu
# Processing Record 36 of Set 6 | petatlan
# Processing Record 37 of Set 6 | zachepylivka
# Processing Record 38 of Set 6 | shakawe
# Processing Record 39 of Set 6 | dongli
# Processing Record 40 of Set 6 | richards bay
# Processing Record 41 of Set 6 | amarpur
# Processing Record 42 of Set 6 | lima
# Processing Record 43 of Set 6 | vanimo
# Processing Record 44 of Set 6 | imeni poliny osipenko
# Processing Record 45 of Set 6 | blackwater
# Processing Record 46 of Set 6 | celestun
# Processing Record 47 of Set 6 | bognor regis
# Processing Record 48 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 49 of Set 6 | north bend
# Processing Record 0 of Set 7 | taltal
# Processing Record 1 of Set 7 | verkh-suetka
# Processing Record 2 of Set 7 | viladecans
# Processing Record 3 of Set 7 | chegdomyn
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | vestmannaeyjar
# Processing Record 6 of Set 7 | sobolevo
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | castrillon
# Processing Record 10 of Set 7 | turinskaya sloboda
# Processing Record 11 of Set 7 | imbituba
# Processing Record 12 of Set 7 | lasa
# Processing Record 13 of Set 7 | itabirito
# Processing Record 14 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 15 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 7 | iquitos
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | jiangdu
# Processing Record 19 of Set 7 | college
# Processing Record 20 of Set 7 | marrakesh
# Processing Record 21 of Set 7 | darnah
# Processing Record 22 of Set 7 | katsuura
# Processing Record 23 of Set 7 | zhangye
# Processing Record 24 of Set 7 | ranong
# Processing Record 25 of Set 7 | mackay
# Processing Record 26 of Set 7 | kemijarvi
# Processing Record 27 of Set 7 | calama
# Processing Record 28 of Set 7 | krasnoye
# Processing Record 29 of Set 7 | ruteng
# Processing Record 30 of Set 7 | nuevitas
# Processing Record 31 of Set 7 | mbandaka
# Processing Record 32 of Set 7 | kanadey
# Processing Record 33 of Set 7 | kongolo
# Processing Record 34 of Set 7 | pasni
# Processing Record 35 of Set 7 | svetlaya
# Processing Record 36 of Set 7 | phan thiet
# Processing Record 37 of Set 7 | baykit
# Processing Record 38 of Set 7 | los llanos de aridane
# Processing Record 39 of Set 7 | santa isabel do rio negro
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | airai
# Processing Record 44 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 7 | bilibino
# Processing Record 46 of Set 7 | hostotipaquillo
# Processing Record 47 of Set 7 | liberal
# Processing Record 48 of Set 7 | demikhovo
# Processing Record 49 of Set 7 | yokadouma
# Processing Record 0 of Set 8 | astipalaia
# City not found. Skipping...
# Processing Record 1 of Set 8 | takoradi
# Processing Record 2 of Set 8 | port hawkesbury
# Processing Record 3 of Set 8 | camacha
# Processing Record 4 of Set 8 | qom
# Processing Record 5 of Set 8 | broken hill
# Processing Record 6 of Set 8 | jacareacanga
# Processing Record 7 of Set 8 | taoudenni
# Processing Record 8 of Set 8 | uinskoye
# Processing Record 9 of Set 8 | chara
# Processing Record 10 of Set 8 | lokosovo
# Processing Record 11 of Set 8 | pizhanka
# Processing Record 12 of Set 8 | lagoa vermelha
# Processing Record 13 of Set 8 | mlonggo
# Processing Record 14 of Set 8 | ulladulla
# Processing Record 15 of Set 8 | sanchor
# Processing Record 16 of Set 8 | mar del plata
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | alta floresta
# Processing Record 19 of Set 8 | xichang
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | bure
# Processing Record 22 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 8 | tigil
# Processing Record 26 of Set 8 | talcahuano
# Processing Record 27 of Set 8 | wilmington
# Processing Record 28 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | mexico
# Processing Record 31 of Set 8 | luknovo
# Processing Record 32 of Set 8 | druzhba
# Processing Record 33 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 8 | taywarah
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 8 | norman wells
# Processing Record 38 of Set 8 | tecoanapa
# Processing Record 39 of Set 8 | sept-iles
# Processing Record 40 of Set 8 | garm
# City not found. Skipping...
# Processing Record 41 of Set 8 | obo
# Processing Record 42 of Set 8 | maldonado
# Processing Record 43 of Set 8 | labuhan
# Processing Record 44 of Set 8 | kharela
# Processing Record 45 of Set 8 | mahibadhoo
# Processing Record 46 of Set 8 | lashio
# Processing Record 47 of Set 8 | kokopo
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | yabrud
# Processing Record 0 of Set 9 | muroto
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | chicama
# Processing Record 3 of Set 9 | aguilas
# Processing Record 4 of Set 9 | bilma
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | guerrero negro
# Processing Record 7 of Set 9 | san julian
# Processing Record 8 of Set 9 | palestine
# Processing Record 9 of Set 9 | kasongo-lunda
# Processing Record 10 of Set 9 | yangambi
# Processing Record 11 of Set 9 | port hedland
# Processing Record 12 of Set 9 | vertientes
# Processing Record 13 of Set 9 | dalbandin
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | olinda
# Processing Record 16 of Set 9 | businga
# Processing Record 17 of Set 9 | matara
# Processing Record 18 of Set 9 | pirogovo
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 9 | khromtau
# Processing Record 22 of Set 9 | madras
# Processing Record 23 of Set 9 | rovaniemi
# Processing Record 24 of Set 9 | yar-sale
# Processing Record 25 of Set 9 | sao filipe
# Processing Record 26 of Set 9 | corinto
# Processing Record 27 of Set 9 | shibetsu
# Processing Record 28 of Set 9 | pavlovskiy posad
# Processing Record 29 of Set 9 | timra
# Processing Record 30 of Set 9 | san policarpo
# Processing Record 31 of Set 9 | miles city
# Processing Record 32 of Set 9 | manavalakurichi
# Processing Record 33 of Set 9 | westport
# Processing Record 34 of Set 9 | meadow lake
# Processing Record 35 of Set 9 | hanover
# Processing Record 36 of Set 9 | aykhal
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | hobbs
# Processing Record 39 of Set 9 | labytnangi
# Processing Record 40 of Set 9 | carutapera
# Processing Record 41 of Set 9 | glodeni
# Processing Record 42 of Set 9 | chanute
# Processing Record 43 of Set 9 | khagrachari
# City not found. Skipping...
# Processing Record 44 of Set 9 | clyde river
# Processing Record 45 of Set 9 | mianyang
# Processing Record 46 of Set 9 | frolovo
# Processing Record 47 of Set 9 | pocoes
# Processing Record 48 of Set 9 | ostrovnoy
# Processing Record 49 of Set 9 | husavik
# Processing Record 0 of Set 10 | benidorm
# Processing Record 1 of Set 10 | palmer
# Processing Record 2 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 10 | beysehir
# Processing Record 4 of Set 10 | port-cartier
# Processing Record 5 of Set 10 | carauari
# Processing Record 6 of Set 10 | biscarrosse
# Processing Record 7 of Set 10 | lockhart
# Processing Record 8 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 10 | gurupa
# Processing Record 10 of Set 10 | nantucket
# Processing Record 11 of Set 10 | kalianget
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | yenagoa
# Processing Record 14 of Set 10 | kudat
# Processing Record 15 of Set 10 | iquique
# Processing Record 16 of Set 10 | fort frances
# Processing Record 17 of Set 10 | atambua
# Processing Record 18 of Set 10 | butembo
# Processing Record 19 of Set 10 | san jose
# Processing Record 20 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 10 | herat
# Processing Record 22 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 10 | ahipara
# Processing Record 24 of Set 10 | stornoway
# Processing Record 25 of Set 10 | wasilla
# Processing Record 26 of Set 10 | hays
# Processing Record 27 of Set 10 | xining
# Processing Record 28 of Set 10 | pachino
# Processing Record 29 of Set 10 | sabang
# Processing Record 30 of Set 10 | bathsheba
# Processing Record 31 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 10 | rodeo
# Processing Record 33 of Set 10 | touros
# Processing Record 34 of Set 10 | jennings
# Processing Record 35 of Set 10 | swellendam
# Processing Record 36 of Set 10 | kankan
# Processing Record 37 of Set 10 | vangaindrano
# Processing Record 38 of Set 10 | vila franca do campo
# Processing Record 39 of Set 10 | synya
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | akkudah
# City not found. Skipping...
# Processing Record 42 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 10 | liverpool
# Processing Record 44 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 10 | izumo
# Processing Record 46 of Set 10 | umm lajj
# Processing Record 47 of Set 10 | skjervoy
# Processing Record 48 of Set 10 | nakamura
# Processing Record 49 of Set 10 | kuching
# Processing Record 0 of Set 11 | bandarbeyla
# Processing Record 1 of Set 11 | iqaluit
# Processing Record 2 of Set 11 | barraute
# Processing Record 3 of Set 11 | manono
# Processing Record 4 of Set 11 | kieta
# Processing Record 5 of Set 11 | puerto narino
# Processing Record 6 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 11 | berlevag
# Processing Record 8 of Set 11 | tungao
# Processing Record 9 of Set 11 | babushkin
# Processing Record 10 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 11 | meulaboh
# Processing Record 12 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 13 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 11 | sangar
# Processing Record 15 of Set 11 | taikang
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 11 | charters towers
# Processing Record 19 of Set 11 | adelanto
# Processing Record 20 of Set 11 | montrose
# Processing Record 21 of Set 11 | jablah
# Processing Record 22 of Set 11 | vana-vigala
# Processing Record 23 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 24 of Set 11 | yumen
# Processing Record 25 of Set 11 | capaci
# Processing Record 26 of Set 11 | laramie
# Processing Record 27 of Set 11 | avera
# Processing Record 28 of Set 11 | naryan-mar
# Processing Record 29 of Set 11 | tromso
# Processing Record 30 of Set 11 | tibacuy
# Processing Record 31 of Set 11 | jayanca
# Processing Record 32 of Set 11 | ambovombe
# Processing Record 33 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 11 | fort nelson
# Processing Record 35 of Set 11 | khorixas
# Processing Record 36 of Set 11 | kotma
# Processing Record 37 of Set 11 | rocha
# Processing Record 38 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 11 | lavumisa
# Processing Record 40 of Set 11 | kysyl-syr
# Processing Record 41 of Set 11 | yulara
# Processing Record 42 of Set 11 | itarema
# Processing Record 43 of Set 11 | la rioja
# Processing Record 44 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | lovington
# Processing Record 46 of Set 11 | souillac
# Processing Record 47 of Set 11 | aquiraz
# Processing Record 48 of Set 11 | san quintin
# Processing Record 49 of Set 11 | kichmengskiy gorodok
# Processing Record 0 of Set 12 | wanning
# Processing Record 1 of Set 12 | defiance
# Processing Record 2 of Set 12 | muros
# Processing Record 3 of Set 12 | pointe michel
# Processing Record 4 of Set 12 | san francisco
# Processing Record 5 of Set 12 | dargaville
# Processing Record 6 of Set 12 | dongling
# Processing Record 7 of Set 12 | neiafu
# Processing Record 8 of Set 12 | sao gabriel da cachoeira
# Processing Record 9 of Set 12 | ketchikan
# Processing Record 10 of Set 12 | honiara
# Processing Record 11 of Set 12 | kruisfontein
# Processing Record 12 of Set 12 | nampula
# Processing Record 13 of Set 12 | abu samrah
# Processing Record 14 of Set 12 | tete
# Processing Record 15 of Set 12 | santiago del estero
# Processing Record 16 of Set 12 | tunceli
# Processing Record 17 of Set 12 | trincomalee
# Processing Record 18 of Set 12 | lamu
# Processing Record 19 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 12 | chishtian mandi
# Processing Record 21 of Set 12 | fairview
# Processing Record 22 of Set 12 | mana
# Processing Record 23 of Set 12 | velika plana
# Processing Record 24 of Set 12 | mehamn
# Processing Record 25 of Set 12 | seydi
# Processing Record 26 of Set 12 | kodinsk
# Processing Record 27 of Set 12 | san rafael del sur
# Processing Record 28 of Set 12 | moscow
# Processing Record 29 of Set 12 | ust-kut
# Processing Record 30 of Set 12 | masvingo
# Processing Record 31 of Set 12 | eyl
# Processing Record 32 of Set 12 | goundi
# Processing Record 33 of Set 12 | labuan
# Processing Record 34 of Set 12 | coahuayana
# Processing Record 35 of Set 12 | nara
# Processing Record 36 of Set 12 | kamenka
# Processing Record 37 of Set 12 | chengde
# Processing Record 38 of Set 12 | nouadhibou
# Processing Record 39 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 12 | ko samui
# Processing Record 41 of Set 12 | matagami
# Processing Record 42 of Set 12 | jumla
# Processing Record 43 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 12 | risod
# Processing Record 45 of Set 12 | tilichiki
# Processing Record 46 of Set 12 | san martin
# Processing Record 47 of Set 12 | hualmay
# Processing Record 48 of Set 12 | laerdalsoyri
# Processing Record 49 of Set 12 | fairburn
# Processing Record 0 of Set 13 | andros town
# Processing Record 1 of Set 13 | marsa matruh
# Processing Record 2 of Set 13 | mingshui
# Processing Record 3 of Set 13 | tucurui
# Processing Record 4 of Set 13 | pocone
# Processing Record 5 of Set 13 | marana
# Processing Record 6 of Set 13 | hirara
# Processing Record 7 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | port blair
# Processing Record 9 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 13 | hobyo
# Processing Record 11 of Set 13 | cockburn town
# Processing Record 12 of Set 13 | kupang
# Processing Record 13 of Set 13 | lovozero
# Processing Record 14 of Set 13 | grand gaube
# Processing Record 15 of Set 13 | sioux lookout
# Processing Record 16 of Set 13 | bauchi
# Processing Record 17 of Set 13 | raudeberg
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | alekseyevsk
# Processing Record 20 of Set 13 | bosaso
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | gazli
# Processing Record 23 of Set 13 | benton harbor
# Processing Record 24 of Set 13 | dujuma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    rikitea -23.1203 -134.9692     26.72        76          31        3.74
# 1   san luis -33.2950  -66.3356     12.65        49           0        3.67
# 2   ust-maya  60.4167  134.5333     -0.65        99         100        1.45
# 3   thompson  55.7435  -97.8558     -8.91        79         100        3.09
# 4  lyantonde  -0.4031   31.1572     15.82        95          56        1.37
#
#   Country        Date
# 0      PF  1680314883
# 1      AR  1680314601
# 2      RU  1680314885
# 3      CA  1680314885
# 4      UG  1680314885

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          rikitea -23.1203 -134.9692     26.72        76          31
# 1         san luis -33.2950  -66.3356     12.65        49           0
# 2         ust-maya  60.4167  134.5333     -0.65        99         100
# 3         thompson  55.7435  -97.8558     -8.91        79         100
# 4        lyantonde  -0.4031   31.1572     15.82        95          56
#
#          Wind Speed Country        Date
# City_ID
# 0              3.74      PF  1680314883
# 1              3.67      AR  1680314601
# 2              1.45      RU  1680314885
# 3              3.09      CA  1680314885
# 4              1.37      UG  1680314885

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

x_data_lat = city_data_df["Lat"]
y_data_temp = city_data_df["Max Temp"]
norm_date = time.strftime("%Y-%m-%d", time.gmtime(city_data_df["Date"][0]))

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({norm_date})")
plt.scatter(x_data_lat, y_data_temp,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Tempreature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_data_lat = city_data_df["Lat"]
y_data_hum = city_data_df["Humidity"]

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity({norm_date})")
plt.scatter(x_data_lat, y_data_hum,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_data_lat = city_data_df["Lat"]
y_data_cloud = city_data_df["Cloudiness"]

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({norm_date})")
plt.scatter(x_data_lat, y_data_cloud,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_data_lat = city_data_df["Lat"]
y_data_winds = city_data_df["Wind Speed"]

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({norm_date})")
plt.scatter(x_data_lat, y_data_winds,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress(x_value, y_value):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    return(slope, intercept, rvalue, pvalue, stderr)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2              ust-maya  60.4167  134.5333     -0.65        99         100
# 3              thompson  55.7435  -97.8558     -8.91        79         100
# 5                  hilo  19.7297 -155.0900     25.85        78          75
# 8        severo-kurilsk  50.6789  156.1250      0.97        70          14
# 11            jamestown  42.0970  -79.2353     11.77        87         100
#
#          Wind Speed Country        Date
# City_ID
# 2              1.45      RU  1680314885
# 3              3.09      CA  1680314885
# 5              7.20      US  1680314701
# 8              4.50      RU  1680314887
# 11             5.66      US  1680314632

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df= city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            rikitea -23.1203 -134.9692     26.72        76          31
# 1           san luis -33.2950  -66.3356     12.65        49           0
# 4          lyantonde  -0.4031   31.1572     15.82        95          56
# 6            mataura -46.1927  168.8643     20.62        50           3
# 7        east london -33.0153   27.9116     17.06        78           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.74      PF  1680314883
# 1              3.67      AR  1680314601
# 4              1.37      UG  1680314885
# 6              1.47      NZ  1680314886
# 7              2.12      ZA  1680314886

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_temp = northern_hemi_df["Max Temp"]

regress_data = linear_regress(x_data_lat,y_data_temp)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_temp, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(5,-20),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: -0.8949703959830326

# %%
# Linear regression on Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_temp = southern_hemi_df["Max Temp"]

regress_data = linear_regress(x_data_lat,y_data_temp)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")
plt.scatter(x_data_lat, y_data_temp,  edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.6633043069158157

# %% [markdown]
#  **Discussion about the linear relationship:**
#
# Based on the data summary from the both the Northern and Southern Hemispheres, it can be observed that there is a strong /moderate correlation between the distance from the equator and the increase in temperature i.e. the further from the equator the lower the max temperature/the closer to the equator the higher the max temperature. The Northern hemisphere data has strong negative linear correlation, and the Southern hemisphere has a moderate positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_hum = northern_hemi_df["Humidity"]

regress_data = linear_regress(x_data_lat,y_data_hum)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_hum, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(50,15),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.311913596921334

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_hum = southern_hemi_df["Humidity"]

regress_data = linear_regress(x_data_lat,y_data_hum)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_hum, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-55,42),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.43808490185034915

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Based on the data summary from the both the Northern and Southern Hemispheres, it can be observed that there is a weak or very weak correlation between the distance from the equator and the percentage of humidity at the various cities i.e. the distance from the equator has no material impact on humidity. The Northern hemisphere data has weak positive linear correlation, and the Southern hemisphere has a weak positive correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_cloud = northern_hemi_df["Cloudiness"]

regress_data = linear_regress(x_data_lat,y_data_cloud)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_cloud, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45,25),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.20435927746994087

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_cloud = southern_hemi_df["Cloudiness"]

regress_data = linear_regress(x_data_lat,y_data_cloud)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_cloud, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55,65),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.37481625384973494

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Based on the data summary from the both the Northern and Southern Hemispheres, it can  be observed that there is a weak or very weak correlation between the distance from the equator and the level of cloudiness at the various cities i.e. the distance from the equator has no material impact on the level of cloud cover. The Northern hemisphere data has a very weak positive linear correlation, and the Southern hemisphere has a weak positive correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_winds = northern_hemi_df["Wind Speed"]

regress_data = linear_regress(x_data_lat,y_data_winds)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_winds, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(5,15),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.294035601110919

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_winds = southern_hemi_df["Wind Speed"]

regress_data = linear_regress(x_data_lat,y_data_winds)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_winds, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-55,7.5),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: -0.3549671461925408

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Based on the data summary from the both the Northern and Southern Hemispheres, it can be observed that there is a weak or very weak correlation between the distance from the equator and the wind speed as measured at the various cities i.e. the distance from the equator has no material impact on the wind speed. The Northern hemisphere data has a very weak positive linear correlation, and the Southern hemisphere has a weak positive correlation.
