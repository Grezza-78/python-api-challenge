# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | brokopondo
# Processing Record 5 of Set 1 | makat
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | san policarpo
# Processing Record 9 of Set 1 | namatanai
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | suntar
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | inhambane
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | saint-marc
# Processing Record 21 of Set 1 | knysna
# Processing Record 22 of Set 1 | palmares do sul
# Processing Record 23 of Set 1 | beringovskiy
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | okha
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | jinka
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | nan
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | okhotsk
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | calabar
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | north myrtle beach
# Processing Record 43 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 1 | doha
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | korem
# Processing Record 47 of Set 1 | nova olimpia
# Processing Record 48 of Set 1 | dunmore town
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | vanavara
# Processing Record 0 of Set 2 | ures
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | asau
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | waiouru
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | laguna
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | ravar
# Processing Record 13 of Set 2 | hobyo
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 16 of Set 2 | khani
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | balsas
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 2 | yakeshi
# Processing Record 24 of Set 2 | whitehorse
# Processing Record 25 of Set 2 | wamba
# Processing Record 26 of Set 2 | grand-santi
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | portsmouth
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | pascagoula
# Processing Record 32 of Set 2 | sitka
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | kahului
# Processing Record 35 of Set 2 | anshun
# Processing Record 36 of Set 2 | beira
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | isangel
# Processing Record 40 of Set 2 | jining
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | kalabo
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | turan
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | abu dhabi
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | sur
# Processing Record 49 of Set 2 | clyde river
# Processing Record 0 of Set 3 | iberia
# Processing Record 1 of Set 3 | morant bay
# Processing Record 2 of Set 3 | otacilio costa
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | naze
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | oranjemund
# Processing Record 7 of Set 3 | garachine
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | abu kamal
# Processing Record 12 of Set 3 | medea
# Processing Record 13 of Set 3 | vertou
# Processing Record 14 of Set 3 | bend
# Processing Record 15 of Set 3 | tahe
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | atambua
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | sola
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | susanino
# Processing Record 24 of Set 3 | peringat
# Processing Record 25 of Set 3 | mount pleasant
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | shenzhen
# Processing Record 30 of Set 3 | stornoway
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | mildura
# Processing Record 36 of Set 3 | mayo
# Processing Record 37 of Set 3 | marawi
# Processing Record 38 of Set 3 | santa lucia
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | irupi
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | sorland
# Processing Record 45 of Set 3 | bitung
# Processing Record 46 of Set 3 | lima
# Processing Record 47 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 0 of Set 4 | honiara
# Processing Record 1 of Set 4 | raga
# Processing Record 2 of Set 4 | deputatskiy
# Processing Record 3 of Set 4 | leningradskiy
# Processing Record 4 of Set 4 | nao-me-toque
# City not found. Skipping...
# Processing Record 5 of Set 4 | yar-sale
# Processing Record 6 of Set 4 | sinazongwe
# Processing Record 7 of Set 4 | talcahuano
# Processing Record 8 of Set 4 | oriximina
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | coahuayana
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | atuona
# Processing Record 13 of Set 4 | kaputa
# Processing Record 14 of Set 4 | senneterre
# Processing Record 15 of Set 4 | le port
# Processing Record 16 of Set 4 | chulman
# Processing Record 17 of Set 4 | susanville
# Processing Record 18 of Set 4 | san javier
# Processing Record 19 of Set 4 | tchollire
# Processing Record 20 of Set 4 | phan thiet
# Processing Record 21 of Set 4 | alexandria
# Processing Record 22 of Set 4 | chazuta
# Processing Record 23 of Set 4 | shirgaon
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 4 | qiongshan
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | matara
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | tilichiki
# Processing Record 31 of Set 4 | lar
# Processing Record 32 of Set 4 | sept-iles
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | tres picos
# Processing Record 36 of Set 4 | praia
# Processing Record 37 of Set 4 | turukhansk
# Processing Record 38 of Set 4 | hami
# Processing Record 39 of Set 4 | santa cruz
# Processing Record 40 of Set 4 | najran
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | ternate
# Processing Record 43 of Set 4 | changji
# Processing Record 44 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | butaritari
# Processing Record 46 of Set 4 | tan an
# Processing Record 47 of Set 4 | mehriz
# Processing Record 48 of Set 4 | el alto
# Processing Record 49 of Set 4 | nampula
# Processing Record 0 of Set 5 | kawalu
# Processing Record 1 of Set 5 | alice springs
# Processing Record 2 of Set 5 | rawson
# Processing Record 3 of Set 5 | puerto colombia
# Processing Record 4 of Set 5 | kedungwuni
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | chicontepec
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | ascension
# Processing Record 9 of Set 5 | cap malheureux
# Processing Record 10 of Set 5 | parsabad
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | klyuchi
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | lumding
# Processing Record 15 of Set 5 | zhuhai
# Processing Record 16 of Set 5 | irati
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | mackay
# Processing Record 19 of Set 5 | puerto ayacucho
# Processing Record 20 of Set 5 | kenai
# Processing Record 21 of Set 5 | qaqortoq
# Processing Record 22 of Set 5 | batagay
# Processing Record 23 of Set 5 | buala
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 26 of Set 5 | padang
# Processing Record 27 of Set 5 | roma
# Processing Record 28 of Set 5 | alyangula
# Processing Record 29 of Set 5 | pansemal
# Processing Record 30 of Set 5 | angra dos reis
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | zhanakorgan
# Processing Record 33 of Set 5 | horsham
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | chernyshevsk
# Processing Record 36 of Set 5 | half moon bay
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | usak
# Processing Record 39 of Set 5 | gimli
# Processing Record 40 of Set 5 | sao jose da coroa grande
# Processing Record 41 of Set 5 | leticia
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | lavrentiya
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | natal
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | plouzane
# Processing Record 48 of Set 5 | tazovskiy
# Processing Record 49 of Set 5 | longhua
# Processing Record 0 of Set 6 | nemuro
# Processing Record 1 of Set 6 | akdepe
# Processing Record 2 of Set 6 | inongo
# Processing Record 3 of Set 6 | gizo
# Processing Record 4 of Set 6 | san carlos de bariloche
# Processing Record 5 of Set 6 | papara
# Processing Record 6 of Set 6 | evensk
# Processing Record 7 of Set 6 | orlik
# Processing Record 8 of Set 6 | port-gentil
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | cayenne
# Processing Record 12 of Set 6 | almeirim
# Processing Record 13 of Set 6 | begun
# Processing Record 14 of Set 6 | hanyang
# Processing Record 15 of Set 6 | fort nelson
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | stokmarknes
# Processing Record 18 of Set 6 | surt
# Processing Record 19 of Set 6 | farrukhnagar
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | arraial do cabo
# Processing Record 22 of Set 6 | troitsko-pechorsk
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | ketchikan
# Processing Record 25 of Set 6 | mattru
# Processing Record 26 of Set 6 | marathon
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | lipari
# Processing Record 29 of Set 6 | quartz hill
# Processing Record 30 of Set 6 | paamiut
# Processing Record 31 of Set 6 | henties bay
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | jalu
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | pacific grove
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | humberto de campos
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | vienna
# Processing Record 41 of Set 6 | wakkanai
# Processing Record 42 of Set 6 | huangnihe
# Processing Record 43 of Set 6 | bremerton
# Processing Record 44 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 6 | hargeysa
# Processing Record 46 of Set 6 | powell
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | constitucion
# Processing Record 49 of Set 6 | eyl
# Processing Record 0 of Set 7 | ouro fino
# Processing Record 1 of Set 7 | norman wells
# Processing Record 2 of Set 7 | normandin
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 | la rioja
# Processing Record 5 of Set 7 | lac du bonnet
# Processing Record 6 of Set 7 | chapais
# Processing Record 7 of Set 7 | lamar
# Processing Record 8 of Set 7 | bulgan
# Processing Record 9 of Set 7 | sorong
# Processing Record 10 of Set 7 | lingao
# Processing Record 11 of Set 7 | nara
# Processing Record 12 of Set 7 | lagoa
# Processing Record 13 of Set 7 | san pedro
# Processing Record 14 of Set 7 | swidwin
# Processing Record 15 of Set 7 | parczew
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | itupiranga
# Processing Record 18 of Set 7 | coquimbo
# Processing Record 19 of Set 7 | kasongo-lunda
# Processing Record 20 of Set 7 | gilgit
# Processing Record 21 of Set 7 | kuliyapitiya
# Processing Record 22 of Set 7 | pichayevo
# Processing Record 23 of Set 7 | waingapu
# Processing Record 24 of Set 7 | novo aripuana
# Processing Record 25 of Set 7 | sao felix do xingu
# Processing Record 26 of Set 7 | basoko
# Processing Record 27 of Set 7 | wajir
# Processing Record 28 of Set 7 | tuktoyaktuk
# Processing Record 29 of Set 7 | great yarmouth
# Processing Record 30 of Set 7 | pemangkat
# Processing Record 31 of Set 7 | nabire
# Processing Record 32 of Set 7 | dwarka
# Processing Record 33 of Set 7 | puerto escondido
# Processing Record 34 of Set 7 | khanpur
# Processing Record 35 of Set 7 | burns lake
# Processing Record 36 of Set 7 | tokur
# Processing Record 37 of Set 7 | atikokan
# Processing Record 38 of Set 7 | shelburne
# Processing Record 39 of Set 7 | moerai
# Processing Record 40 of Set 7 | gladstone
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | inta
# Processing Record 43 of Set 7 | iqaluit
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | plettenberg bay
# Processing Record 46 of Set 7 | nizhniy tsasuchey
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | ukiah
# Processing Record 49 of Set 7 | shenkursk
# Processing Record 0 of Set 8 | grand gaube
# Processing Record 1 of Set 8 | oktyabrskoye
# Processing Record 2 of Set 8 | mikhaylovka
# Processing Record 3 of Set 8 | emmett
# Processing Record 4 of Set 8 | along
# Processing Record 5 of Set 8 | mount holly
# Processing Record 6 of Set 8 | amahai
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | viransehir
# Processing Record 9 of Set 8 | harper
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | inuvik
# Processing Record 12 of Set 8 | san julian
# Processing Record 13 of Set 8 | snyder
# Processing Record 14 of Set 8 | kashi
# Processing Record 15 of Set 8 | asyut
# Processing Record 16 of Set 8 | siemiatycze
# Processing Record 17 of Set 8 | chicama
# Processing Record 18 of Set 8 | nyurba
# Processing Record 19 of Set 8 | starodub
# Processing Record 20 of Set 8 | tank
# Processing Record 21 of Set 8 | changde
# Processing Record 22 of Set 8 | road town
# Processing Record 23 of Set 8 | marrakesh
# Processing Record 24 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 8 | tateyama
# Processing Record 26 of Set 8 | novyy urengoy
# Processing Record 27 of Set 8 | kieta
# Processing Record 28 of Set 8 | bathsheba
# Processing Record 29 of Set 8 | kharp
# Processing Record 30 of Set 8 | nsanje
# Processing Record 31 of Set 8 | mandalgovi
# Processing Record 32 of Set 8 | zhaotong
# Processing Record 33 of Set 8 | togitsu
# Processing Record 34 of Set 8 | bilma
# Processing Record 35 of Set 8 | san quintin
# Processing Record 36 of Set 8 | jacareacanga
# Processing Record 37 of Set 8 | manado
# Processing Record 38 of Set 8 | saint-henri-de-levis
# City not found. Skipping...
# Processing Record 39 of Set 8 | harunabad
# Processing Record 40 of Set 8 | breyten
# Processing Record 41 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 8 | akyab
# Processing Record 43 of Set 8 | hihya
# Processing Record 44 of Set 8 | csabrendek
# Processing Record 45 of Set 8 | arica
# Processing Record 46 of Set 8 | pundaguitan
# Processing Record 47 of Set 8 | veroli
# Processing Record 48 of Set 8 | hundested
# Processing Record 49 of Set 8 | port hardy
# Processing Record 0 of Set 9 | auki
# Processing Record 1 of Set 9 | kilmez
# City not found. Skipping...
# Processing Record 2 of Set 9 | rio gallegos
# Processing Record 3 of Set 9 | mushie
# Processing Record 4 of Set 9 | panzhihua
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | longyearbyen
# Processing Record 7 of Set 9 | kuching
# Processing Record 8 of Set 9 | cabinda
# Processing Record 9 of Set 9 | bentiu
# Processing Record 10 of Set 9 | kurtamysh
# Processing Record 11 of Set 9 | gojra
# Processing Record 12 of Set 9 | talnakh
# Processing Record 13 of Set 9 | gandajika
# Processing Record 14 of Set 9 | lewiston
# Processing Record 15 of Set 9 | sarangani
# Processing Record 16 of Set 9 | sungaipenuh
# Processing Record 17 of Set 9 | bundaberg
# Processing Record 18 of Set 9 | angra
# City not found. Skipping...
# Processing Record 19 of Set 9 | ascoli piceno
# Processing Record 20 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 9 | pasni
# Processing Record 22 of Set 9 | segou
# Processing Record 23 of Set 9 | bethel
# Processing Record 24 of Set 9 | ahipara
# Processing Record 25 of Set 9 | kathu
# Processing Record 26 of Set 9 | husavik
# Processing Record 27 of Set 9 | calvinia
# Processing Record 28 of Set 9 | spalene porici
# Processing Record 29 of Set 9 | margate
# Processing Record 30 of Set 9 | berlevag
# Processing Record 31 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 9 | markova
# Processing Record 33 of Set 9 | formosa
# Processing Record 34 of Set 9 | goose creek
# Processing Record 35 of Set 9 | neryungri
# Processing Record 36 of Set 9 | moranbah
# Processing Record 37 of Set 9 | manono
# Processing Record 38 of Set 9 | cabra
# Processing Record 39 of Set 9 | binga
# Processing Record 40 of Set 9 | ambovombe
# Processing Record 41 of Set 9 | marsh harbour
# Processing Record 42 of Set 9 | banikoara
# Processing Record 43 of Set 9 | sisimiut
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | nushki
# Processing Record 46 of Set 9 | ust-kut
# Processing Record 47 of Set 9 | vestmannaeyjar
# Processing Record 48 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 9 | adrar
# Processing Record 0 of Set 10 | kim
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | totma
# Processing Record 3 of Set 10 | katsuura
# Processing Record 4 of Set 10 | pokhara
# Processing Record 5 of Set 10 | miri
# Processing Record 6 of Set 10 | caucaia
# Processing Record 7 of Set 10 | labuhan
# Processing Record 8 of Set 10 | qatana
# Processing Record 9 of Set 10 | peniche
# Processing Record 10 of Set 10 | sompeta
# Processing Record 11 of Set 10 | villa rica
# Processing Record 12 of Set 10 | killybegs
# Processing Record 13 of Set 10 | devils lake
# Processing Record 14 of Set 10 | aranos
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | axim
# Processing Record 17 of Set 10 | wanaka
# Processing Record 18 of Set 10 | hatillo
# Processing Record 19 of Set 10 | kitui
# Processing Record 20 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 10 | estelle
# Processing Record 23 of Set 10 | olafsvik
# Processing Record 24 of Set 10 | sao joao da barra
# Processing Record 25 of Set 10 | ca mau
# Processing Record 26 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 10 | kempsey
# Processing Record 28 of Set 10 | beidao
# Processing Record 29 of Set 10 | kavaratti
# Processing Record 30 of Set 10 | saint-francois
# Processing Record 31 of Set 10 | kusa
# Processing Record 32 of Set 10 | my tho
# Processing Record 33 of Set 10 | toba
# Processing Record 34 of Set 10 | segezha
# Processing Record 35 of Set 10 | mukhen
# Processing Record 36 of Set 10 | masty
# Processing Record 37 of Set 10 | bodaybo
# Processing Record 38 of Set 10 | masindi
# Processing Record 39 of Set 10 | namibe
# Processing Record 40 of Set 10 | katangli
# Processing Record 41 of Set 10 | batticaloa
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | cortez
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 10 | pauini
# Processing Record 47 of Set 10 | prince rupert
# Processing Record 48 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 10 | lorengau
# Processing Record 0 of Set 11 | cullman
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | caetite
# Processing Record 4 of Set 11 | ouahigouya
# Processing Record 5 of Set 11 | bambous virieux
# Processing Record 6 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 11 | eyrarbakki
# Processing Record 8 of Set 11 | rome
# Processing Record 9 of Set 11 | chalinze
# Processing Record 10 of Set 11 | la sarre
# Processing Record 11 of Set 11 | shihezi
# Processing Record 12 of Set 11 | limon
# Processing Record 13 of Set 11 | lazaro cardenas
# Processing Record 14 of Set 11 | orange
# Processing Record 15 of Set 11 | paithan
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | sibu
# Processing Record 18 of Set 11 | arenapolis
# Processing Record 19 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 11 | camacupa
# Processing Record 21 of Set 11 | bolshaya atnya
# City not found. Skipping...
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | indian head
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | kesova gora
# Processing Record 26 of Set 11 | usinsk
# Processing Record 27 of Set 11 | altamira
# Processing Record 28 of Set 11 | angola
# Processing Record 29 of Set 11 | broceni
# Processing Record 30 of Set 11 | burica
# City not found. Skipping...
# Processing Record 31 of Set 11 | soure
# Processing Record 32 of Set 11 | azanka
# Processing Record 33 of Set 11 | saint-pierre
# Processing Record 34 of Set 11 | yubileynyy
# Processing Record 35 of Set 11 | santa vitoria
# Processing Record 36 of Set 11 | sohag
# Processing Record 37 of Set 11 | chara
# Processing Record 38 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 39 of Set 11 | chifeng
# Processing Record 40 of Set 11 | dubuque
# Processing Record 41 of Set 11 | richards bay
# Processing Record 42 of Set 11 | sibiti
# Processing Record 43 of Set 11 | nizhniy baskunchak
# Processing Record 44 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 11 | motygino
# Processing Record 46 of Set 11 | makakilo city
# Processing Record 47 of Set 11 | meadow lake
# Processing Record 48 of Set 11 | nishihara
# Processing Record 49 of Set 11 | jequie
# Processing Record 0 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | uarini
# Processing Record 2 of Set 12 | santa marta
# Processing Record 3 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 4 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 5 of Set 12 | girard
# Processing Record 6 of Set 12 | yuanping
# Processing Record 7 of Set 12 | iztapa
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | malanje
# Processing Record 10 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 11 of Set 12 | quelimane
# Processing Record 12 of Set 12 | launceston
# Processing Record 13 of Set 12 | ngunguru
# Processing Record 14 of Set 12 | ulladulla
# Processing Record 15 of Set 12 | kutum
# Processing Record 16 of Set 12 | durant
# Processing Record 17 of Set 12 | guaymas
# Processing Record 18 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 19 of Set 12 | ulaanbaatar
# Processing Record 20 of Set 12 | severo-yeniseyskiy
# Processing Record 21 of Set 12 | natchez
# Processing Record 22 of Set 12 | taybad
# Processing Record 23 of Set 12 | cabedelo
# Processing Record 24 of Set 12 | sabya
# Processing Record 25 of Set 12 | le vauclin
# Processing Record 26 of Set 12 | dawson creek
# Processing Record 27 of Set 12 | atar
# Processing Record 28 of Set 12 | diffa
# Processing Record 29 of Set 12 | bar harbor
# Processing Record 30 of Set 12 | raudeberg
# Processing Record 31 of Set 12 | rodrigues alves
# Processing Record 32 of Set 12 | winston-salem
# Processing Record 33 of Set 12 | luanda
# Processing Record 34 of Set 12 | xinyu
# Processing Record 35 of Set 12 | manggar
# Processing Record 36 of Set 12 | hendek
# Processing Record 37 of Set 12 | catuday
# Processing Record 38 of Set 12 | altay
# Processing Record 39 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 12 | ndele
# Processing Record 42 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 12 | bloemfontein
# Processing Record 44 of Set 12 | tyumentsevo
# Processing Record 45 of Set 12 | wolgast
# Processing Record 46 of Set 12 | kidal
# Processing Record 47 of Set 12 | tura
# Processing Record 48 of Set 12 | haines junction
# Processing Record 49 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 0 of Set 13 | porto novo
# Processing Record 1 of Set 13 | evanston
# Processing Record 2 of Set 13 | buraydah
# Processing Record 3 of Set 13 | villarrica
# Processing Record 4 of Set 13 | lapua
# Processing Record 5 of Set 13 | olinda
# Processing Record 6 of Set 13 | morwell
# Processing Record 7 of Set 13 | meinung
# City not found. Skipping...
# Processing Record 8 of Set 13 | palmer
# Processing Record 9 of Set 13 | nedjo
# Processing Record 10 of Set 13 | santa rosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         mareeba -17.0000  145.4333     25.40        95           8
# 1   leningradskiy  69.3833  178.4167    -12.38        80          85
# 2          barrow  71.2906 -156.7887    -10.99        79         100
# 3         sayansk  54.1088  102.1648      9.93        71          97
# 4  victoria point -27.5833  153.3000     25.06        88         100
#
#    Wind Speed Country        Date
# 0        1.97      AU  1680081316
# 1        3.33      RU  1680081316
# 2        7.20      US  1680081316
# 3        2.08      RU  1680081317
# 4        3.52      AU  1680081317

# %%
# Export the City_Data into a csv
# city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               mareeba -17.0000  145.4333     25.40        95           8
# 1         leningradskiy  69.3833  178.4167    -12.38        80          85
# 2                barrow  71.2906 -156.7887    -10.99        79         100
# 3               sayansk  54.1088  102.1648      9.93        71          97
# 4        victoria point -27.5833  153.3000     25.06        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.97      AU  1680081316
# 1              3.33      RU  1680081316
# 2              7.20      US  1680081316
# 3              2.08      RU  1680081317
# 4              3.52      AU  1680081317

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_data_lat = city_data_df["Lat"]
y_data_temp = city_data_df["Max Temp"]
# norm_date = 

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.scatter(x_data_lat, y_data_temp,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Tempreature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_data_lat = city_data_df["Lat"]
y_data_hum = city_data_df["Humidity"]
# norm_date = 


# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.scatter(x_data_lat, y_data_hum,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_data_lat = city_data_df["Lat"]
y_data_cloud = city_data_df["Cloudiness"]
# norm_date = 

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.scatter(x_data_lat, y_data_cloud,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_data_lat = city_data_df["Lat"]
y_data_winds = city_data_df["Wind Speed"]
# norm_date = 

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.scatter(x_data_lat, y_data_winds,edgecolors = "black", alpha = 0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress(x_value, y_value):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    return(slope, intercept, rvalue, pvalue, stderr)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        leningradskiy  69.3833  178.4167    -12.38        80          85
# 2               barrow  71.2906 -156.7887    -10.99        79         100
# 3              sayansk  54.1088  102.1648      9.93        71          97
# 5                 hovd  48.0056   91.6419      9.76        19          53
# 6            machalpur  24.1333   76.3000     35.16        13          29
#
#          Wind Speed Country        Date
# City_ID
# 1              3.33      RU  1680081316
# 2              7.20      US  1680081316
# 3              2.08      RU  1680081317
# 5              2.16      MN  1680081318
# 6              3.31      IN  1680081146

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df= city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               mareeba -17.0000  145.4333     25.40        95           8
# 4        victoria point -27.5833  153.3000     25.06        88         100
# 9                faanui -16.4833 -151.7500     27.92        75          48
# 10         punta arenas -53.1500  -70.9167      1.06        93          75
# 15              rikitea -23.1203 -134.9692     26.20        78          85
#
#          Wind Speed Country        Date
# City_ID
# 0              1.97      AU  1680081316
# 4              3.52      AU  1680081317
# 9              4.75      PF  1680081319
# 10             2.57      CL  1680081137
# 15             2.36      PF  1680081322

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_temp = northern_hemi_df["Max Temp"]

regress_data = linear_regress(x_data_lat,y_data_temp)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_temp, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(5,-20),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: -0.8874118856892377

# %%
# Linear regression on Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_temp = southern_hemi_df["Max Temp"]

regress_data = linear_regress(x_data_lat,y_data_temp)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")
plt.scatter(x_data_lat, y_data_temp,  edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.7219430659527792

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_hum = northern_hemi_df["Humidity"]

regress_data = linear_regress(x_data_lat,y_data_hum)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_hum, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(50,15),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.34127148545661057

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_hum = southern_hemi_df["Humidity"]

regress_data = linear_regress(x_data_lat,y_data_hum)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_hum, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-55,42),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.27712499188272527

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_cloud = northern_hemi_df["Cloudiness"]

regress_data = linear_regress(x_data_lat,y_data_cloud)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_cloud, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45,32),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.16249532332265273

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_cloud = southern_hemi_df["Cloudiness"]

regress_data = linear_regress(x_data_lat,y_data_cloud)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_cloud, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55,65),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.37481625384973494

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data_lat = northern_hemi_df["Lat"]
y_data_winds = northern_hemi_df["Wind Speed"]

regress_data = linear_regress(x_data_lat,y_data_winds)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_winds, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(5,15),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: 0.10678026171407679

# %%
# Southern Hemisphere
x_data_lat = southern_hemi_df["Lat"]
y_data_winds = southern_hemi_df["Wind Speed"]

regress_data = linear_regress(x_data_lat,y_data_winds)
regress_values = x_data_lat * regress_data[0] + regress_data[1]
line_eq = "y = " + str(round(regress_data[0],2)) + "x + " + str(round(regress_data[1],2))

print(f"The r-value is: {regress_data[2]}")

# Incorporate the other graph properties
plt.scatter(x_data_lat, y_data_winds, edgecolors = "black", alpha = 0.75)
plt.plot(x_data_lat, regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq,(-55,9),fontsize=15,color="red")

# # Show plot
plt.tight_layout()
plt.show()
# Out:
# The r-value is: -0.4315782510312485

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
